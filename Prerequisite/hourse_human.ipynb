# %%
import tensorflow as tf
import numpy as np

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=(300, 300),
    batch_size=128, 
    label_mode='binary'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 train_dataset = tf.keras.utils.image_dataset_from_directory(
# ----> 2     TRAIN_DIR,
#       3     image_size=(300, 300),
#       4     batch_size=128,
#       5     label_mode='binary'
#
# NameError: name 'TRAIN_DIR' is not defined

# %%
rescale_layer = tf.keras.layers.Rescaling(scale=1./255)

train_dataset_scaled = train_dataset.map(
    lambda image, label: (rescale_layer(image), label)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 rescale_layer = tf.keras.layers.Rescaling(scale=1./255)
#       2
# ----> 3 train_dataset_scaled = train_dataset.map(
#       4     lambda image, label: (rescale_layer(image), label)
#       5 )
#
# NameError: name 'train_dataset' is not defined

# %%
train_dataset_final = (
    train_dataset_scaled
    .cache()
    .shuffle(buffer_size=1000)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)
