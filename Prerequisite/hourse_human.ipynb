# %%
import tensorflow as tf
import numpy as np

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=(300, 300),
    batch_size=128, 
    label_mode='binary'
)
