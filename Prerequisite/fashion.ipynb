# %%
import tensorflow as tf
import numpy as np

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 11us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 127s 5us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 15s 3us/step

# %%
model = tf.keras.Sequential([
    # the shape is expected to be (28, 28)
    tf.keras.Input(shape=(28, 28)),
    # Flatten change the shape from square into single array
    tf.keras.layers.Flatten(),
    # This is hidden layers with 128 neurons with ReLu activation function
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    # This is the output layer which has the same amount of neuron as the #classes
    # With softmax activation function
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer= tf.optimizers.Adam(), 
              loss= 'sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6635 - loss: 10.9388
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7167 - loss: 0.7149
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7757 - loss: 0.6005
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8124 - loss: 0.5236
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8171 - loss: 0.5159

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.8112 - loss: 0.5284
# [0.5453933477401733, 0.8080000281333923]

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = None):
        if logs['loss'] < 0.4:
            print('Loss is low so cancelling training!')
            self.model.stop_training = True

# %%
model.fit(train_images, train_labels, epochs=5, callbacks=[myCallback()])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8257 - loss: 0.4837
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8272 - loss: 0.4903
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8323 - loss: 0.4735
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8303 - loss: 0.4775
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8319 - loss: 0.4764
